# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Upload file, convert to dataframe
attendance_df = pd.read_csv('../CSP_Data/activities_attendance.csv')
attendance_df
# Out:
#       Attendance ID                          Activity Name  \
# 0               NaN             Surfing 101 Middle School
# 1               NaN             Surfing 101 Middle School
# 2               NaN             Surfing 101 Middle School
# 3               NaN             Surfing 101 Middle School
# 4               NaN             Surfing 101 Middle School
# 5               NaN             Surfing 101 Middle School
# 6               NaN             Surfing 101 Middle School
# 7               NaN             Surfing 101 Middle School
# 8               NaN             Surfing 101 Middle School
# 9               NaN             Surfing 101 Middle School
# 10              NaN             Surfing 101 Middle School
# 11              NaN             Surfing 101 Middle School
# 12              NaN             Surfing 101 Middle School
# 13              NaN             Surfing 101 Middle School
# 14              NaN             Surfing 101 Middle School
# 15              NaN             Surfing 101 Middle School
# 16              NaN             Surfing 101 Middle School
# 17              NaN             Surfing 101 Middle School
# 18              NaN             Surfing 101 Middle School
# 19              NaN             Surfing 101 Middle School
# 20              NaN             Surfing 101 Middle School
# 21              NaN             Surfing 101 Middle School
# 22              NaN             Surfing 101 Middle School
# 23              NaN             Surfing 101 Middle School
# 24              NaN             Surfing 101 Middle School
# 25              NaN             Surfing 101 Middle School
# 26              NaN             Surfing 101 Middle School
# 27              NaN             Surfing 101 Middle School
# 28              NaN             Surfing 101 Middle School
# 29              NaN             Surfing 101 Middle School
# ...             ...                                    ...
# 5531            NaN  Surfers In Leadership Training (SILT)
# 5532            NaN  Surfers In Leadership Training (SILT)
# 5533            NaN  Surfers In Leadership Training (SILT)
# 5534            NaN  Surfers In Leadership Training (SILT)
# 5535            NaN  Surfers In Leadership Training (SILT)
# 5536            NaN  Surfers In Leadership Training (SILT)
# 5537            NaN  Surfers In Leadership Training (SILT)
# 5538            NaN  Surfers In Leadership Training (SILT)
# 5539            NaN  Surfers In Leadership Training (SILT)
# 5540            NaN  Surfers In Leadership Training (SILT)
# 5541            NaN  Surfers In Leadership Training (SILT)
# 5542            NaN  Surfers In Leadership Training (SILT)
# 5543            NaN  Surfers In Leadership Training (SILT)
# 5544            NaN  Surfers In Leadership Training (SILT)
# 5545            NaN  Surfers In Leadership Training (SILT)
# 5546            NaN  Surfers In Leadership Training (SILT)
# 5547            NaN  Surfers In Leadership Training (SILT)
# 5548            NaN  Surfers In Leadership Training (SILT)
# 5549            NaN  Surfers In Leadership Training (SILT)
# 5550            NaN  Surfers In Leadership Training (SILT)
# 5551            NaN  Surfers In Leadership Training (SILT)
# 5552            NaN  Surfers In Leadership Training (SILT)
# 5553            NaN  Surfers In Leadership Training (SILT)
# 5554            NaN  Surfers In Leadership Training (SILT)
# 5555            NaN  Surfers In Leadership Training (SILT)
# 5556            NaN  Surfers In Leadership Training (SILT)
# 5557            NaN  Surfers In Leadership Training (SILT)
# 5558            NaN  Surfers In Leadership Training (SILT)
# 5559            NaN  Surfers In Leadership Training (SILT)
# 5560            NaN  Surfers In Leadership Training (SILT)
#
#       Activity Instance ID                                    Activity Label  \
# 0                  3383538                          Aptos Surfing 101 Course
# 5537                          NaN                                     NaN
# 5538                          NaN                                     NaN
# 5539                          NaN                                     NaN
# 5540                          NaN                                     NaN
# 5541                          NaN                                     NaN
# 5542                          NaN                                     NaN
# 5543                          NaN                                     NaN
# 5544                          NaN                                     NaN
# 5545                          NaN                                     NaN
# 5546                          NaN                                     NaN
# 5547                          NaN                                     NaN
# 5548                          NaN                                     NaN
# 5549                          NaN                                     NaN
# 5550                          NaN                                     NaN
# 5551                          NaN                                     NaN
# 5552                          NaN                                     NaN
# 5553                          NaN                                     NaN
# 5554                          NaN                                     NaN
# 5555                          NaN                                     NaN
# 5556                          NaN                                     NaN
# 5557                          NaN                                     NaN
# 5558                          NaN                                     NaN
# 5559                          NaN                                     NaN
# 5560                          NaN                                     NaN
#
#       Individual Activity - Referral Agency  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# ...                                     ...
# 5531                                    NaN
# 5532                                    NaN
# 5533                                    NaN
# 5534                                    NaN
# 5535                                    NaN
# 5536                                    NaN
# 5537                                    NaN
# 5538                                    NaN
# 5539                                    NaN
# 5540                                    NaN
# 5541                                    NaN
# 5542                                    NaN
# 5543                                    NaN
# 5544                                    NaN
# 5545                                    NaN
# 5546                                    NaN
# 5547                                    NaN
# 5548                                    NaN
# 5549                                    NaN
# 5550                                    NaN
# 5551                                    NaN
# 5552                                    NaN
# 5553                                    NaN
# 5554                                    NaN
# 5555                                    NaN
# 5556                                    NaN
# 5557                                    NaN
# 5558                                    NaN
# 5559                                    NaN
# 5560                                    NaN
#
#       Individual Activity - Referral Date
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ...                                   ...
# 5531                                  NaN
# 5532                                  NaN
# 5533                                  NaN
# 5534                                  NaN
# 5535                                  NaN
# 5536                                  NaN
# 5537                                  NaN
# 5538                                  NaN
# 5539                                  NaN
# 5540                                  NaN
# 5541                                  NaN
# 5542                                  NaN
# 5543                                  NaN
# 5544                                  NaN
# 5545                                  NaN
# 5546                                  NaN
# 5547                                  NaN
# 5548                                  NaN
# 5549                                  NaN
# 5550                                  NaN
# 5551                                  NaN
# 5552                                  NaN
# 5553                                  NaN
# 5554                                  NaN
# 5555                                  NaN
# 5556                                  NaN
# 5557                                  NaN
# 5558                                  NaN
# 5559                                  NaN
# 5560                                  NaN
#
# [5561 rows x 13 columns]

# %%
# Check data types
attendance_df.dtypes
# Out:
# Attendance ID                             float64
# Activity Name                              object
# Activity Instance ID                        int64
# Activity Label                             object
# Person ID                                   int64
# Date                                       object
# Attended (y/n)                             object
# Minutes Attended                          float64
# Lead Staff Name                            object
# Individual Activity - Notes               float64
# Individual Activity - Referral Service    float64
# Individual Activity - Referral Agency     float64
# Individual Activity - Referral Date       float64
# dtype: object

# %%
# Drop columns we do not want in schema
attendance_df = attendance_df.drop(columns = ["Attendance ID", "Activity Label", "Lead Staff Name", "Individual Activity - Notes", "Individual Activity - Referral Service", "Individual Activity - Referral Agency", "Individual Activity - Referral Date"])
attendance_df.head()
# Out:
#                 Activity Name  Activity Instance ID  Person ID        Date  \
# 0  Surfing 101 Middle School                3383538   46887178   9/10/2018
# 1  Surfing 101 Middle School                3383538   46887178   9/17/2018
# 2  Surfing 101 Middle School                3383538   46887178   9/24/2018
# 3  Surfing 101 Middle School                3383538   46887178   10/1/2018
# 4  Surfing 101 Middle School                3383538   46887178  10/15/2018
#
#   Attended (y/n)  Minutes Attended
# 0              Y             360.0
# 1              Y             360.0
# 2              Y             360.0
# 3              Y             360.0
# 4              Y             360.0

# %%
# Rename columns
attendance_df = attendance_df.rename(columns={
                          'Person ID':'Participant ID',
                            'Attended (y/n)':'Attended'
})
attendance_df
# Out:
#                               Activity Name  Activity Instance ID  \
# 0                Surfing 101 Middle School                3383538
# 1                Surfing 101 Middle School                3383538
# 2                Surfing 101 Middle School                3383538
# 3                Surfing 101 Middle School                3383538
# 4                Surfing 101 Middle School                3383538
# 5                Surfing 101 Middle School                3383538
# 6                Surfing 101 Middle School                3383538
# 7                Surfing 101 Middle School                3383538
# 8                Surfing 101 Middle School                3383538
# 9                Surfing 101 Middle School                3383538
# 10               Surfing 101 Middle School                3383538
# 11               Surfing 101 Middle School                3383538
# 12               Surfing 101 Middle School                3383538
# 13               Surfing 101 Middle School                3383538
# 14               Surfing 101 Middle School                3383538
# 15               Surfing 101 Middle School                3383538
# 16               Surfing 101 Middle School                3383538
# 17               Surfing 101 Middle School                3383538
# 18               Surfing 101 Middle School                3383538
# 19               Surfing 101 Middle School                3383538
# 20               Surfing 101 Middle School                3383538
# 21               Surfing 101 Middle School                3383538
# 22               Surfing 101 Middle School                3383538
# 23               Surfing 101 Middle School                3383538
# 24               Surfing 101 Middle School                3383538
# 25               Surfing 101 Middle School                3383538
# 26               Surfing 101 Middle School                3383538
# 27               Surfing 101 Middle School                3383538
# 28               Surfing 101 Middle School                3383538
# 29               Surfing 101 Middle School                3383538
# ...                                     ...                   ...
# 5531  Surfers In Leadership Training (SILT)               3621424
# 5532  Surfers In Leadership Training (SILT)               3621424
# 5533  Surfers In Leadership Training (SILT)               3621424
# 5534  Surfers In Leadership Training (SILT)               3621424
# 5535  Surfers In Leadership Training (SILT)               3621424
# 5536  Surfers In Leadership Training (SILT)               3621424
# 5537  Surfers In Leadership Training (SILT)               3621424
# 5538  Surfers In Leadership Training (SILT)               3621424
# 5539  Surfers In Leadership Training (SILT)               3621424
# 5540  Surfers In Leadership Training (SILT)               3621424
# 5541  Surfers In Leadership Training (SILT)               3621424
# 5542  Surfers In Leadership Training (SILT)               3621424
# 5543  Surfers In Leadership Training (SILT)               3621424
# 5544  Surfers In Leadership Training (SILT)               3621424
# 5545  Surfers In Leadership Training (SILT)               3621424
# 5546  Surfers In Leadership Training (SILT)               3621424
# 5547  Surfers In Leadership Training (SILT)               3621424
# 5548  Surfers In Leadership Training (SILT)               3621424
# 5549  Surfers In Leadership Training (SILT)               3621424
# 5550  Surfers In Leadership Training (SILT)               3621424
# 5551  Surfers In Leadership Training (SILT)               3621424
# 5552  Surfers In Leadership Training (SILT)               3621424
# 5553  Surfers In Leadership Training (SILT)               3621424
# 5554  Surfers In Leadership Training (SILT)               3621424
# 5555  Surfers In Leadership Training (SILT)               3621424
# 5556  Surfers In Leadership Training (SILT)               3621424
# Surfing 101                              4981
# Surfing 101 Middle School                 338
# Surfers In Leadership Training (SILT)     242
# Name: Activity Name, dtype: int64

# %%
attendance_df["Activity Instance ID"].value_counts()
# Out:
# 3384580    3185
# 3417045     499
# 3417059     486
# 3474515     237
# 3508595     108
# 3508583      88
# 3517784      85
# 3421146      82
# 3476979      72
# 3383538      70
# 3621424      60
# 3621419      60
# 3472807      55
# 3621418      30
# 3440566      29
# 3473499      24
# 3476373      23
# 3527022      20
# 3474149      18
# 3528219      17
# 3429906      17
# 3476388      17
# 3440661      16
# 3476343      15
# 3475642      14
# 3499217      14
# 3420417      14
# 3620598      14
# 3535966      13
# 3620940      12
# 3420508      12
# 3474121      12
# 3538029      12
# 3528375      11
# 3526992      10
# 3621415      10
# 3535885      10
# 3536052       9
# 3499320       9
# 3454339       8
# 3488181       8
# 3528332       8
# 3499380       8
# 3538008       7
# 3620656       6
# 3480978       5
# 3620600       5
# 3499367       5
# 3527068       4
# 3620979       4
# 3476438       4
# Name: Activity Instance ID, dtype: int64

# %%
# Find any repeat participants
repeat_participant = attendance_df.groupby(["Participant ID"])
repeat_participant.agg({"Activity Instance ID": "nunique"})
# Out:
#                 Activity Instance ID
# Participant ID
# 46842888                           3
# 46843252                           1
# 46843305                           1
# 46843348                           1
# 46843349                           2
# 46843398                           1
# 46843808                           2
# 46843825                           2
# 46843828                           1
# 46843859                           2
# 46843869                           1
# 46843888                           1
# 46844454                           1
# 46844856                           1
# 46845067                           1
# 46845494                           1
# 46846077                           1
# 46846095                           1
# 46846158                           1
# 46846606                           2
# 46847012                          16
# 46847083                           1
# 46847639                           1
# 46848314                           3
# 46848575                           1
# 46848601                           2
# 46848682                           2
# 46848962                          10
# 46848990                           2
# 46849073                           2
# ...                              ...
# 47027386                           1
# 47228286                           1
# 47255849                           1
# 47283620                           1
# 47333793                           1
# 47343704                          10
# 47346915                           7
# 47363253                           1
# 47400264                           1
# 47411223                           1
# 47411254                           2
# 47433624                           1
# 47433636                           1
# 47433658                           2
# 47433659                           1
# 47440447                           1
# 47440470                           1
# 47444510                           1
# 47513499                           1
# 47577793                           3
# 47600251                           1
# 47627212                           2
# 47685963                           1
# 47728952                           1
# 47745654                           3
# 47793648                           1
# 47814984                           1
# 47835429                           1
# 47878255                           2
# 48068072                           1
#
# [427 rows x 1 columns]

# %%
# Found that there are 427 more students included on this sheet than the student profile sheet 
# Will need to drop attendees who are not included in the students demographic profile sheet
# when perfomring merge between the 2 tables

# This exploratory pull of a weird student shows that it is possible to attend 16 different activities
# this can be explained if a student only attends one off field trips or attends field trips in addition to 
# surfing 101 courses

weird_student = attendance_df[attendance_df["Participant ID"] == 46847012]
weird_student.head()
# Out:
#     Activity Name  Activity Instance ID  Participant ID       Date Attended  \
# 270   Surfing 101               3384580        46847012   2/8/2019        Y
# 271   Surfing 101               3384580        46847012  2/11/2019        Y
# 272   Surfing 101               3384580        46847012  2/13/2019        Y
# 273   Surfing 101               3384580        46847012  2/15/2019        Y
# 274   Surfing 101               3384580        46847012  2/20/2019        Y
#
#      Minutes Attended
# 270             300.0
# 271             180.0
# 272             180.0
# 273             300.0
# 274             180.0

# %% [markdown]
# # Create df by Program - SILT / Surfing 101 MS / Surfing 101 HS

# %%
# Filter by Program -SILT
is_silt = attendance_df['Activity Name'] == 'Surfers In Leadership Training (SILT)'
is_silt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Activity Name, dtype: bool

# %%
# Df for silt
silt_df = attendance_df[is_silt]
silt_df.head()
# Out:
#                               Activity Name  Activity Instance ID  \
# 4266  Surfers In Leadership Training (SILT)               3421146
# 4267  Surfers In Leadership Training (SILT)               3421146
# 4268  Surfers In Leadership Training (SILT)               3421146
# 4269  Surfers In Leadership Training (SILT)               3421146
# 4270  Surfers In Leadership Training (SILT)               3421146
#
#       Participant ID      Date Attended  Minutes Attended
# 4266        46843398  8/1/2018        N               0.0
# 4267        46843398  8/2/2018        N               0.0
# 4268        46853927  8/1/2018        N               0.0
# 4269        46853927  8/2/2018        N               0.0
# 4270        46854059  8/1/2018        Y             480.0

# %%
## Filter by Program - Middle School 101
is_surfing_101_MS = attendance_df['Activity Name'] == 'Surfing 101 Middle School '
is_surfing_101_MS.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Activity Name, dtype: bool

# %%
# Df for MS Surfing 101
surf_101_MS_df = attendance_df[is_surfing_101_MS]
surf_101_MS_df.head()
# Out:
#                 Activity Name  Activity Instance ID  Participant ID  \
# 0  Surfing 101 Middle School                3383538        46887178
# 1  Surfing 101 Middle School                3383538        46887178
# 2  Surfing 101 Middle School                3383538        46887178
# 3  Surfing 101 Middle School                3383538        46887178
# 4  Surfing 101 Middle School                3383538        46887178
#
#          Date Attended  Minutes Attended
# 0   9/10/2018        Y             360.0
# 1   9/17/2018        Y             360.0
# 2   9/24/2018        Y             360.0
# 3   10/1/2018        Y             360.0
# 4  10/15/2018        Y             360.0

# %%
# Filter by HS Surfing 101
surf_101_HS = attendance_df['Activity Name'] == 'Surfing 101'
surf_101_HS.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Activity Name, dtype: bool

# %%
# Df for HS surfing 101
surf_101_HS_df = attendance_df[surf_101_HS]
surf_101_HS_df.head()
# Out:
#    Activity Name  Activity Instance ID  Participant ID       Date Attended  \
# 70   Surfing 101               3384580        46843252  8/20/2018        Y
# 71   Surfing 101               3384580        46843252  8/22/2018        Y
# 72   Surfing 101               3384580        46843252  8/24/2018        Y
# 73   Surfing 101               3384580        46843252  8/27/2018        Y
# 74   Surfing 101               3384580        46843252  8/29/2018        Y
#
#     Minutes Attended
# 70             180.0
# 71             180.0
# 72             300.0
# 73             180.0
# 74             180.0

# %%
# Amount of classes attended per students
value_counts_HS = surf_101_HS_df["Participant ID"].value_counts()
value_counts_HS.head()
# Out:
# 46848962    106
# 46875282    104
# 46876799    103
# 46869531    102
# 46863178    102
# Name: Participant ID, dtype: int64

# %%
# Who attended one class
one_time_HS = value_counts_HS == 1
one_time_HS.head()
# Out:
# 46848962    False
# 46875282    False
# 46876799    False
# 46869531    False
# 46863178    False
# Name: Participant ID, dtype: bool

# %%
# Isolate students who only attended one class
one_timers_HS = value_counts_HS[one_time_HS]
one_timers_HS.head()
# Out:
# 46862359    1
# 46858392    1
# 47027338    1
# 46862041    1
# 46889250    1
# Name: Participant ID, dtype: int64

# %%
# Df of Students who only attended one class of Surfing 101 HS
one_timers_HS_df = pd.DataFrame(value_counts_HS[one_time_HS], index=None)
one_timers_HS_df.reset_index(inplace=True) 
one_timers_HS_df = one_timers_HS_df.rename(columns={
                    'index':'Participant ID',
                    'Participant ID':'Classes Attended'
})
one_timers_HS_df.head()
# Out:
#    Participant ID  Classes Attended
# 0        46862359                 1
# 1        46858392                 1
# 2        47027338                 1
# 3        46862041                 1
# 4        46889250                 1

# %%
# Value counts for Surfing 101 MS 
surf_101_MS_df['Participant ID'].value_counts().head()
# Out:
# 46897549    33
# 46904597    18
# 46901108    18
# 46895808    18
# 46907807    18
# Name: Participant ID, dtype: int64

# %%
# Values Counts for SILT
silt_df['Participant ID'].value_counts().head()
# Out:
# 46876991    12
# 46864770    12
# 46878556    10
# 46848962    10
# 46864094     9
# Name: Participant ID, dtype: int64

# %% [markdown]
# #  New DFs based on Activity Instance ID

# %%
#Check Dtypes and convert to Datetime
surf_101_MS_df.dtypes


surf_101_MS_df["Date"] = pd.to_datetime(surf_101_MS_df["Date"])
# Out:
# /Users/patrickslademahoney/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
surf_101_MS_df["Activity Instance ID"].value_counts()
# Out:
# 3508595    108
# 3508583     88
# 3476979     72
# 3383538     70
# Name: Activity Instance ID, dtype: int64

# %%
# Sort by Activity Instance ID, 
sem_1 = surf_101_MS_df[surf_101_MS_df["Activity Instance ID"]== 3508595]
sem_1.head()
# Out:
#                    Activity Name  Activity Instance ID  Participant ID  \
# 5046  Surfing 101 Middle School                3508595        46891989
# 5047  Surfing 101 Middle School                3508595        46891989
# 5048  Surfing 101 Middle School                3508595        46891989
# 5049  Surfing 101 Middle School                3508595        46891989
# 5050  Surfing 101 Middle School                3508595        46891989
#
#            Date Attended  Minutes Attended
# 5046 2019-04-01        N               0.0
# 5047 2019-04-08        N               0.0
# 5048 2019-04-15        N               0.0
# 5049 2019-04-22        Y             225.0
# 5050 2019-04-29        Y             225.0

# %%
# Create Data Frames that can be filtered for Attendance percentage 
sem_1_df = pd.DataFrame(sem_1)
sem_1_df.head()
# Out:
#                    Activity Name  Activity Instance ID  Participant ID  \
# 5046  Surfing 101 Middle School                3508595        46891989
# 5047  Surfing 101 Middle School                3508595        46891989
# 5048  Surfing 101 Middle School                3508595        46891989
# 5049  Surfing 101 Middle School                3508595        46891989
# 5050  Surfing 101 Middle School                3508595        46891989
#
#            Date Attended  Minutes Attended
# 5046 2019-04-01        N               0.0
# 5047 2019-04-08        N               0.0
# 5048 2019-04-15        N               0.0
# 5049 2019-04-22        Y             225.0
# 5050 2019-04-29        Y             225.0

# %%
sem_2 = surf_101_MS_df[surf_101_MS_df["Activity Instance ID"]== 3508583 ]
sem_2["Date"].value_counts()
# Out:
# 2019-03-18    11
# 2019-03-11    11
# 2019-03-04    11
# 2019-02-25    11
# 2019-02-18    11
# 2019-02-11    11
# 2019-02-04    11
# 2019-01-28    11
# Name: Date, dtype: int64

# %%
sem_3 = surf_101_MS_df[surf_101_MS_df["Activity Instance ID"]== 3476979]
sem_3["Date"].value_counts()
# Out:
# 2019-01-14    8
# 2019-01-07    8
# 2018-12-17    8
# 2018-12-10    8
# 2018-12-03    8
# 2018-11-26    8
# 2018-11-19    8
# 2018-11-12    8
# 2018-11-05    8
# Name: Date, dtype: int64

# %%
sem_4 = surf_101_MS_df[surf_101_MS_df["Activity Instance ID"]== 3383538]
sem_4["Date"].value_counts()
# Out:
# 2018-10-01    10
# 2018-09-24    10
# 2018-09-17    10
# 2018-09-10    10
# 2018-10-29    10
# 2018-10-22    10
# 2018-10-15    10
# Name: Date, dtype: int64

# %%
# Create New group the MS Surfing 101 Classes by Activity Instance ID
# Going to Create New DF's so I can sort by Activity Instance ID and see & Attended

# Need to group students by Activity Instance ID 
# Then pull the attended Y or N count and make a percentage

# %% [markdown]
# ## Separating Code

# %%
#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model

yes = surf_101_MS_df[surf_101_MS_df["Attended"] == "Y"]
no = surf_101_MS_df[surf_101_MS_df["Attended"] == "N"]
yes.head()
# Out:
#                 Activity Name  Activity Instance ID  Participant ID  \
# 0  Surfing 101 Middle School                3383538        46887178
# 1  Surfing 101 Middle School                3383538        46887178
# 2  Surfing 101 Middle School                3383538        46887178
# 3  Surfing 101 Middle School                3383538        46887178
# 4  Surfing 101 Middle School                3383538        46887178
#
#         Date Attended  Minutes Attended
# 0 2018-09-10        Y             360.0
# 1 2018-09-17        Y             360.0
# 2 2018-09-24        Y             360.0
# 3 2018-10-01        Y             360.0
# 4 2018-10-15        Y             360.0

# %%
# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

yes_attended.head()
# Out:
# Participant ID
# 46887178    13
# 46891897     7
# 46891989    11
# 46892101     5
# 46893742     5
# Name: Attended, dtype: int64

# %%
no_attended.head()
# Out:
# Participant ID
# 46887178    2
# 46891989    5
# 46892101    4
# 46893742    3
# 46895808    3
# Name: Attended, dtype: int64

# %%
#Validating Total Y Count  -- Checks out Participant 46887178 has 13 y and 2 N
surf_101_MS_df[surf_101_MS_df["Participant ID"] == 46887178]
# Out:
#                    Activity Name  Activity Instance ID  Participant ID  \
# 0     Surfing 101 Middle School                3383538        46887178
# 1     Surfing 101 Middle School                3383538        46887178
# 2     Surfing 101 Middle School                3383538        46887178
# 3     Surfing 101 Middle School                3383538        46887178
# 4     Surfing 101 Middle School                3383538        46887178
# 5     Surfing 101 Middle School                3383538        46887178
# 6     Surfing 101 Middle School                3383538        46887178
# 4958  Surfing 101 Middle School                3508583        46887178
# 4959  Surfing 101 Middle School                3508583        46887178
# 4960  Surfing 101 Middle School                3508583        46887178
# 4961  Surfing 101 Middle School                3508583        46887178
# 4962  Surfing 101 Middle School                3508583        46887178
# 4963  Surfing 101 Middle School                3508583        46887178
# 4964  Surfing 101 Middle School                3508583        46887178
# 4965  Surfing 101 Middle School                3508583        46887178
#
#            Date Attended  Minutes Attended
# 0    2018-09-10        Y             360.0
# 5143  Surfing 101 Middle School                3508595        46907807
# 5144  Surfing 101 Middle School                3508595        46907807
# 5145  Surfing 101 Middle School                3508595        46908729
# 5146  Surfing 101 Middle School                3508595        46908729
# 5147  Surfing 101 Middle School                3508595        46908729
# 5148  Surfing 101 Middle School                3508595        46908729
# 5149  Surfing 101 Middle School                3508595        46908729
# 5150  Surfing 101 Middle School                3508595        46908729
# 5151  Surfing 101 Middle School                3508595        46908729
# 5152  Surfing 101 Middle School                3508595        46908729
# 5153  Surfing 101 Middle School                3508595        46908729
#
# [338 rows x 3 columns]

# %%
# Make New DF to create new Surfing 101 Total Days Attended DF 
surf_101_MS_total_days_attended_df = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Attended_Y": yes_attended,
    "Attended_N": no_attended
})
surf_101_MS_total_days_attended_df
# Out:
#                             Activity Name  Attended_Y  Attended_N
# Participant ID
# 46887178        Surfing 101 Middle School          13         2.0
# 46891897        Surfing 101 Middle School           7         NaN
# 46891989        Surfing 101 Middle School          11         5.0
# 46892101        Surfing 101 Middle School           5         4.0
# 46893742        Surfing 101 Middle School           5         3.0
# 46894320        Surfing 101 Middle School          16         NaN
# 46895808        Surfing 101 Middle School          15         3.0
# 46896561        Surfing 101 Middle School           7         1.0
# 46897422        Surfing 101 Middle School           9         NaN
# 46897487        Surfing 101 Middle School           7         NaN
# 46897549        Surfing 101 Middle School          31         2.0
# 46897577        Surfing 101 Middle School           5         2.0
# 46898292        Surfing 101 Middle School          12         3.0
# 46898738        Surfing 101 Middle School           7         1.0
# 46898818        Surfing 101 Middle School           8         NaN
# 46898869        Surfing 101 Middle School          16         NaN
# 46899499        Surfing 101 Middle School           7         2.0
# 46899585        Surfing 101 Middle School           3         5.0
# 46900269        Surfing 101 Middle School           4         4.0
# 46900329        Surfing 101 Middle School           7         1.0
# 46901108        Surfing 101 Middle School          16         2.0
# 46901198        Surfing 101 Middle School           8         1.0
# 46904597        Surfing 101 Middle School          17         1.0
# 46906175        Surfing 101 Middle School           8         1.0
# 46906440        Surfing 101 Middle School          13         2.0
# 46907807        Surfing 101 Middle School          13         5.0
# 46908206        Surfing 101 Middle School           6         3.0
# 46908729        Surfing 101 Middle School           3         6.0

# %%
# Replace NaN values with 0 since they are students who did not miss an attendance
surf_101_MS_total_days_attended_df['Attended_N'] = surf_101_MS_total_days_attended_df['Attended_N'].fillna(0)
surf_101_MS_total_days_attended_df.head()
# Out:
#                             Activity Name  Attended_Y  Attended_N
# Participant ID
# 46887178        Surfing 101 Middle School          13         2.0
# 46891897        Surfing 101 Middle School           7         0.0
# 46891989        Surfing 101 Middle School          11         5.0
# 46892101        Surfing 101 Middle School           5         4.0
# 46893742        Surfing 101 Middle School           5         3.0

# %%
# Check and Change DTYPE to INT
surf_101_MS_total_days_attended_df.dtypes
surf_101_MS_total_days_attended_df["Attended_N"].astype(int)
# Out:
# Participant ID
# 46887178    2
# 46891897    0
# 46891989    5
# 46892101    4
# 46893742    3
# 46894320    0
# 46895808    3
# 46896561    1
# 46897422    0
# 46897487    0
# 46897549    2
# 46897577    2
# 46898292    3
# 46898738    1
# 46898818    0
# 46898869    0
# 46899499    2
# 46899585    5
# 46900269    4
# 46900329    1
# 46901108    2
# 46901198    1
# 46904597    1
# 46906175    1
# 46906440    2
# 46907807    5
# 46908206    3
# 46908729    6
# Name: Attended_N, dtype: int64

# %%
yes = df1[df1["Attended"] == "Y"]
no = df1[df1["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df1_clean = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Activity Instance ID": '3383538',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df1_clean['Attended_N'] = df1_clean['Attended_N'].fillna(0)

df1_clean["Percent Attend"] = ((df1_clean["Attended_Y"])/(df1_clean["Attended_Y"]+ df1_clean["Attended_N"]))

# %%
# Create a for loop to loop through data and 

groupby_att = attendance_df.groupby("Activity Instance ID")
big_list = []

for activity, df in groupby_att:
    participant_ids = set(df["Participant ID"].tolist())
    for participant in participant_ids:
        record = {"Activity": activity, 
                "Participant ID": participant,
                 "Attendance": 1}
        big_list.append(record)
    
    
#     number_of_days = len(set(df["Date"].tolist()))
#     attended = df.groupby("Participant ID")["Attended"].value_counts()
#     print(attended)
#     print(number_of_days)
#     print(activity)
    #df["Percent Attend"] = ((df["Attended_Y"])/(df["Attended_Y"]+ df["Attended_N"]))
    #df.drop_duplicates(subset = ["Participant ID"], inplace= True)
    #print(df)

# %%
new_attendance_df = pd.DataFrame(big_list)
new_attendance_df.groupby("Participant ID")["Attendance"].sum()
# Need to create a new dataframe with the sum included
# Out:
#      Activity  Attendance  Participant ID  Total Programs Attended
# 0     3383538           1        46906440                      NaN
# 1     3383538           1        46897577                      NaN
# 2     3383538           1        46887178                      NaN
# 3     3383538           1        46897549                      NaN
# 4     3383538           1        46897487                      NaN
# 5     3383538           1        46894320                      NaN
# 6     3383538           1        46898292                      NaN
# 7     3383538           1        46891989                      NaN
# 8     3383538           1        46898869                      NaN
# 9     3383538           1        46891897                      NaN
# 10    3384580           1        46868996                      NaN
# 11    3384580           1        46857740                      NaN
# 12    3384580           1        46846095                      NaN
# 13    3384580           1        46875282                      NaN
# 14    3384580           1        46872724                      NaN
# 15    3384580           1        46869531                      NaN
# 16    3384580           1        46868638                      NaN
# 17    3384580           1        46847012                      NaN
# 18    3384580           1        46855204                      NaN
# 19    3384580           1        46866343                      NaN
# 20    3384580           1        46863147                      NaN
# 21    3384580           1        46885803                      NaN
# 22    3384580           1        46863022                      NaN
# 23    3384580           1        46872115                      NaN
# 24    3384580           1        47027379                      NaN
# 25    3384580           1        46868024                      NaN
# 26    3384580           1        46854847                      NaN
# 27    3384580           1        46876799                      NaN
# 28    3384580           1        46892864                      NaN
# 29    3384580           1        46848962                      NaN
# ..        ...         ...             ...                      ...
# 670   3621419           1        47577793                      NaN
# 671   3621419           1        46856130                      NaN
# 672   3621419           1        46848962                      NaN
# 673   3621419           1        46847012                      NaN
# 674   3621419           1        46864770                      NaN
# 675   3621419           1        46867140                      NaN
# 676   3621419           1        46857834                      NaN
# 677   3621419           1        46878556                      NaN
# 678   3621419           1        46864094                      NaN
# 679   3621419           1        46876991                      NaN
# 680   3621424           1        46893706                      NaN
# 681   3621424           1        46908175                      NaN
# 682   3621424           1        46892821                      NaN
# 683   3621424           1        46882582                      NaN
# 684   3621424           1        47411223                      NaN
# 685   3621424           1        46893469                      NaN
# 686   3621424           1        46872993                      NaN
# 687   3621424           1        46900770                      NaN
# 688   3621424           1        46876069                      NaN
# 689   3621424           1        46864039                      NaN
# 690   3621424           1        46852396                      NaN
# 691   3621424           1        46901050                      NaN
# 692   3621424           1        47433659                      NaN
# 693   3621424           1        46896188                      NaN
# 694   3621424           1        46877766                      NaN
# 695   3621424           1        46860241                      NaN
# 696   3621424           1        46894801                      NaN
# 697   3621424           1        46872027                      NaN
# 698   3621424           1        46869856                      NaN
# 699   3621424           1        46894961                      NaN
#
# [700 rows x 4 columns]

# %%
# groupby_att = attendance_df.groupby("Activity Instance ID")
# big_list = []

# for activity, df in groupby_att:


#     number_of_days = len(set(df["Date"].tolist()))
#     attended = df.groupby("Participant ID")["Attended"].value_counts()
#     print(attended)
#     print(number_of_days)
#     print(activity)
#     #df["Percent Attend"] = ((df["Attended_Y"])/(df["Attended_Y"]+ df["Attended_N"]))
#     #df.drop_duplicates(subset = ["Participant ID"], inplace= True)
#     #print(df)
# Out:
# Participant ID  Attended
# 46887178        Y           7
# 46891897        Y           7
# 46891989        Y           7
# 46894320        Y           7
# 46897487        Y           7
# 46897549        Y           6
#                 N           1
# 46897577        Y           5
#                 N           2
# 46898292        Y           7
# 46898869        Y           7
# 46906440        Y           7
# Name: Attended, dtype: int64
# 7
# 3383538
# Participant ID  Attended
# 46843252        Y           80
#                 N           20
# 46846095        N           64
#                 Y           36
# 46847012        Y           40
#                 N            1
# 46848962        Y           69
#                 N           31
# 46854847        Y           53
#                 N           47
# 46855204        Y           76
#                 N           24
# 46857181        Y           77
#                 N           23
# 46857186        Y           67
#                 N           33
# 46857740        Y           67
#                 N           33
# 46858992        Y           58
#                 N           42
# 46861904        Y           61
#                 N           39
# 46862430        Y           42
#                 N           33
# 46863022        Y           66
#                 N           34
# 46863077        N           52
#                 Y           48
# 46863147        Y           66
#                 N           34
#                             ..
# 46868996        Y           61
#                 N           39
# 46869531        Y           84
#                 N           16
# 46871123        Y           81
#                 N           19
# 46872115        N           55
#                 Y           45
# 46872724        N           50
#                 Y           25
# 46873595        Y           60
#                 N           40
# 46873706        N           38
#                 Y           10
# 46875282        Y           64
#                 N           36
# 46876799        Y           78
#                 N           22
# 46877014        N           54
#                 Y           46
# 46879337        Y           31
#                 N           28
# 46885803        Y           32
#                 N           15
# 46886737        Y           67
#                 N           33
# 46892864        Y           68
#                 N           32
# 47027379        Y           17
#                 N            5
# Name: Attended, Length: 74, dtype: int64
# 100
# 3384580
# Participant ID  Attended
# 46857910        N           15
# 46872027        Y           3
# 46872993        Y           2
#                 N           1
# 46876069        N           3
# 46877766        Y           3
# 46882582        Y           3
# 46892821        Y           3
# 46893469        Y           2
#                 N           1
# 46893706        Y           2
#                 N           1
# 46894801        Y           3
# 46894961        Y           2
#                 N           1
# 46896188        Y           3
# 46900770        N           3
# 46901050        Y           3
# 46908175        Y           3
# 47411223        N           3
# 47433659        Y           3
# Name: Attended, dtype: int64
# 3
# 3621424

# %% [markdown]
# ## Separate Activity Instance ID into different groups

# %%
act_id = attendance_df["Activity Instance ID"].tolist()
act_id
# Out:
# [3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3383538,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  3384580,
#  ...]

# %%
#https://www.w3schools.com/python/python_howto_remove_duplicates.asp
# Create a list of the possible unique values in Acitivity Instance ID
# Hoping to filter the DF using this list 

act_id = list(dict.fromkeys(poop))
len(act_id)
# Out:
# 51

# %%
# Validate list length 
attendance_df["Activity Instance ID"].nunique()
# Out:
# 51

# %%
# Split up Data according to Activity Instance ID into new DataFrames 
# Need to do this to be able to convert y and N to digits to get percentage of potential classes attended
# All classes are different amounts of days so percentage needs to be metric used rather than total classes attended

df6 = attendance_df[attendance_df["Activity Instance ID"]== 3420508]
df7 = attendance_df[attendance_df["Activity Instance ID"]== 3421146]
df8 = attendance_df[attendance_df["Activity Instance ID"]== 3429906]
df9 = attendance_df[attendance_df["Activity Instance ID"]== 3440566]
df10 = attendance_df[attendance_df["Activity Instance ID"]== 3440661]
df11 = attendance_df[attendance_df["Activity Instance ID"]== 3454339]
df12 = attendance_df[attendance_df["Activity Instance ID"]== 3472807]
df13= attendance_df[attendance_df["Activity Instance ID"]== 3473499]
df14 = attendance_df[attendance_df["Activity Instance ID"]== 3474121]
df15 = attendance_df[attendance_df["Activity Instance ID"]== 3474149]
df16=attendance_df[attendance_df["Activity Instance ID"]== 3474515]
df17=attendance_df[attendance_df["Activity Instance ID"]== 3475642]
df18=attendance_df[attendance_df["Activity Instance ID"]== 3476343]
df19=attendance_df[attendance_df["Activity Instance ID"]== 3476373]
df20=attendance_df[attendance_df["Activity Instance ID"]== 3476388]
df21=attendance_df[attendance_df["Activity Instance ID"]== 3476438]
df22=attendance_df[attendance_df["Activity Instance ID"]== 3476979]
df23=attendance_df[attendance_df["Activity Instance ID"]== 3480978]
df24=attendance_df[attendance_df["Activity Instance ID"]== 3488181]
df25=attendance_df[attendance_df["Activity Instance ID"]== 3499217]
df26=attendance_df[attendance_df["Activity Instance ID"]== 3499320]
df27=attendance_df[attendance_df["Activity Instance ID"]== 3499367]
df28=attendance_df[attendance_df["Activity Instance ID"]== 3499380]
df29=attendance_df[attendance_df["Activity Instance ID"]== 3508583]
df30=attendance_df[attendance_df["Activity Instance ID"]== 3508595]
df31=attendance_df[attendance_df["Activity Instance ID"]== 3517784]
df32=attendance_df[attendance_df["Activity Instance ID"]== 3526992]
df33=attendance_df[attendance_df["Activity Instance ID"]== 3527022]
df34=attendance_df[attendance_df["Activity Instance ID"]== 3527068]
df35=attendance_df[attendance_df["Activity Instance ID"]== 3528219]
df36=attendance_df[attendance_df["Activity Instance ID"]== 3528332]
df37=attendance_df[attendance_df["Activity Instance ID"]== 3528375]
df38=attendance_df[attendance_df["Activity Instance ID"]== 3535885]
df39=attendance_df[attendance_df["Activity Instance ID"]== 3535966]
df40=attendance_df[attendance_df["Activity Instance ID"]== 3536052]
df41=attendance_df[attendance_df["Activity Instance ID"]== 3538008]
df42=attendance_df[attendance_df["Activity Instance ID"]== 3538029]
df43=attendance_df[attendance_df["Activity Instance ID"]== 3620598]
df44=attendance_df[attendance_df["Activity Instance ID"]== 3620600]
df45=attendance_df[attendance_df["Activity Instance ID"]== 3620656]
df46=attendance_df[attendance_df["Activity Instance ID"]== 3620940]
df47=attendance_df[attendance_df["Activity Instance ID"]== 3620979]
df48=attendance_df[attendance_df["Activity Instance ID"]== 3621415]
df49=attendance_df[attendance_df["Activity Instance ID"]== 3621418]
df50=attendance_df[attendance_df["Activity Instance ID"]== 3621419]
df51=attendance_df[attendance_df["Activity Instance ID"]== 3621424]

# %%
#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model
#
df1 = attendance_df[attendance_df["Activity Instance ID"]== 3383538]
yes = df1[df1["Attended"] == "Y"]
no = df1[df1["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df1_clean = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Activity Instance ID": '3383538',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df1_clean['Attended_N'] = df1_clean['Attended_N'].fillna(0)

df1_clean["Percent Attend"] = ((df1_clean["Attended_Y"])/(df1_clean["Attended_Y"]+ df1_clean["Attended_N"]))

df1_clean
# Out:
#                             Activity Name Activity Instance ID  Attended_Y  \
# Participant ID
# 46887178        Surfing 101 Middle School              3383538           7
# 46891897        Surfing 101 Middle School              3383538           7
# 46891989        Surfing 101 Middle School              3383538           7
# 46894320        Surfing 101 Middle School              3383538           7
# 46897487        Surfing 101 Middle School              3383538           7
# 46897549        Surfing 101 Middle School              3383538           6
# 46897577        Surfing 101 Middle School              3383538           5
# 46898292        Surfing 101 Middle School              3383538           7
# 46898869        Surfing 101 Middle School              3383538           7
# 46906440        Surfing 101 Middle School              3383538           7
#
#                 Attended_N  Percent Attend
# Participant ID
# 46887178               0.0        1.000000
# 46891897               0.0        1.000000
# 46891989               0.0        1.000000
# 46894320               0.0        1.000000
# 46897487               0.0        1.000000
# 46897549               1.0        0.857143
# 46897577               2.0        0.714286
# 46898292               0.0        1.000000
# 46898869               0.0        1.000000
# 46906440               0.0        1.000000

# %%
#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model
df2 = attendance_df[attendance_df["Activity Instance ID"]== 3384580]
yes = df2[df2["Attended"] == "Y"]
no = df2[df2["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df2_clean = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Activity Instance ID": '3384580',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df2_clean['Attended_N'] = df2_clean['Attended_N'].fillna(0)

# 
df2_clean["Percent Attend"] = ((df2_clean["Attended_Y"])/(df2_clean["Attended_Y"]+ df2_clean["Attended_N"]))

# %%
df3 = attendance_df[attendance_df["Activity Instance ID"]== 3417045]

#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model

yes = df3[df3["Attended"] == "Y"]
no = df3[df3["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df3_clean = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Activity Instance ID": '3417045',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df3_clean['Attended_N'] = df3_clean['Attended_N'].fillna(0)

# 
df3_clean["Percent Attend"] = ((df3_clean["Attended_Y"])/(df3_clean["Attended_Y"]+ df3_clean["Attended_N"]))

# %%
##4
#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model

df4 = attendance_df[attendance_df["Activity Instance ID"]== 3417059]
yes = df4[df4["Attended"] == "Y"]
no = df4[df4["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df4_clean = pd.DataFrame({
    "Activity Name": "Surfing 101 Middle School",
    "Activity Instance ID": '3417059',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df4_clean['Attended_N'] = df4_clean['Attended_N'].fillna(0)

# 
df4_clean["Percent Attend"] = ((df4_clean["Attended_Y"])/(df4_clean["Attended_Y"]+ df4_clean["Attended_N"]))

# %%
##5
df5 = attendance_df[attendance_df["Activity Instance ID"]== 3420417]
#Sort Participant ID by Total Attended Y or N so we can count the total number of days attended 
# Machine Learning Model

yes = df5[df5["Attended"] == "Y"]
no = df5[df5["Attended"] == "N"]


# YES Counts
yes_attended = yes.groupby(["Participant ID"]).count()["Attended"]
no_attended = no.groupby(["Participant ID"]).count()["Attended"].round(0)

# Merge together to create new Surfing 101 Total Days Attended DF 
df5_clean = pd.DataFrame({
    "Activity Name": "",
    "Activity Instance ID": '3420417',
    "Attended_Y": yes_attended,
    "Attended_N": no_attended,
    
})


# Replace NaN values with 0 since they are students who did not miss an attendance
df5_clean['Attended_N'] = df5_clean['Attended_N'].fillna(0)

# 
df5_clean["Percent Attend"] = ((df5_clean["Attended_Y"])/(df5_clean["Attended_Y"]+ df5_clean["Attended_N"]))
