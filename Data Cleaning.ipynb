# %%
# Import dependencies
import pandas as pd
import os
from pathlib import Path

# %%
students_df = pd.read_csv('C:/Users/User1/Desktop/City_Surf_Project/CSP_Data/student_demographic.csv')
students_df
# Out:
#             Participant, Parent & Staff Extract Unnamed: 1   Unnamed: 2  \
# 0    Report Creation Date: 9/16/2020 3:40:37 PM        NaN          NaN
# 1                     Agency: City Surf Project        NaN          NaN
# 2                                           NaN        NaN          NaN
# 3                                     Agency ID  Person ID  Person Type
# 4                                         97393   46846158        Youth
# ..                                          ...        ...          ...
# 314                                       97393   46858120        Youth
# 315                                       97393   48846586        Youth
# 316                                       97393   46863569        Youth
# 317                                       97393   46863548        Youth
# 318                                       97393   46865112        Youth
#
#        Unnamed: 3 Unnamed: 4     Unnamed: 5                Unnamed: 6  \
# 0             NaN        NaN            NaN                       NaN
# 1             NaN        NaN            NaN                       NaN
# 2             NaN        NaN            NaN                       NaN
# 3    Registration     Status  Date of Birth            Housing Status
# 4        Complete     Active      9/14/2003  Permanent/Stable Housing
# ..            ...        ...            ...                       ...
# 314      Complete     Active      3/29/2004  Permanent/Stable Housing
# 315      Complete     Active      5/22/2003  Permanent/Stable Housing
# 316      Complete     Active      9/27/2003  Permanent/Stable Housing
# 317      Complete     Active      7/30/2003  Permanent/Stable Housing
# 318      Complete     Active      2/22/2003  Permanent/Stable Housing
#
#              Unnamed: 7 Unnamed: 8     Unnamed: 9  ...  \
# 0                   NaN        NaN            NaN  ...
# 1                   NaN        NaN            NaN  ...
# 2                   NaN        NaN            NaN  ...
# 3        Street Address  Apt./Unit           City  ...
# 4         591 Flood Ave        NaN  San Francisco  ...
# ..                  ...        ...            ...  ...
# 314  1410 Sacramento St        NaN  San Francisco  ...
# 315     131 Victoria St        NaN  San Francisco  ...
# 316      336 Wayland St        NaN  San Francisco  ...
# 317  1340 Sunnydale Ave        NaN  San Francisco  ...
# 318  44 Patton St Apt B        NaN  San Francisco  ...
#
#                                     Unnamed: 22               Unnamed: 23  \
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3    Sexual Orientation/Sexual Identity Specify    Educational Attainment
# 4                                           NaN  Currently attending K-12
# ..                                          ...                       ...
# 314                                         NaN  Currently attending K-12
# 315                                         NaN                       NaN
# 316                                         NaN  Currently attending K-12
# 317                                         NaN  Currently attending K-12
# 318                                         NaN  Currently attending K-12
#
#                       Unnamed: 24               Unnamed: 25  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                School Attending  Specify School Attending
# 4                      Mission HS                       NaN
# ..                            ...                       ...
# 314                     Lowell HS                       NaN
# 315                           NaN                       NaN
# 316  Burton (Phillip and Sala) HS                       NaN
# 317  Burton (Phillip and Sala) HS                       NaN
# 318         Leadership HS Charter                       NaN
#
#              Unnamed: 26        Unnamed: 27       Unnamed: 28  \
# 0                    NaN                NaN               NaN
# 1                    NaN                NaN               NaN
# 2                    NaN                NaN               NaN
# 3    SFUSD record? (y/n)  School Entry Date  SFUSD Entry Date
# 4                  SFUSD          8/20/2018         2/10/2011
# ..                   ...                ...               ...
# 314                SFUSD          8/20/2018         8/24/2009
# 315                SFUSD                NaN               NaN
# 316                SFUSD          8/20/2018         8/25/2008
# 317                SFUSD          8/20/2018         8/25/2008
# 318                SFUSD          8/20/2018         8/25/2008
#
#                     Unnamed: 29                 Unnamed: 30  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3    K-12 Grade Level (FY18-19)  K-12 Grade Level (FY19-20)
# 4                            10                          11
# ..                          ...                         ...
# 314                           9                          10
# 315                         NaN                          11
# 316                          10                          11
# 317                          10                          11
# 318                          10                          11
#
#                 Unnamed: 31
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3    Agency Enrollment Date
# 4           5/14/2019 12:13
# ..                      ...
# 314          10/2/2018 9:27
# 315         2/14/2020 10:10
# 316         2/12/2020 10:15
# 317         2/12/2020 10:16
# 318        12/20/2019 10:29
#
# [319 rows x 32 columns]
