# %%
# Import dependencies
import pandas as pd
import os
from pathlib import Path

# %%
# Upload file, convert to dataframe
students_df = pd.read_csv('C:/Users/User1/Desktop/City_Surf_Project/CSP_Data/student_demographic.csv')
students_df
# Out:
#      Agency ID  Person ID Person Type Registration  Status Date of Birth  \
# 0        97393   46846158       Youth     Complete  Active     9/14/2003
# 1        97393   46857740       Youth     Complete  Active     4/15/2003
# 2        97393   47821880       Youth     Complete  Active     6/27/2002
# 3        97393   46893469       Youth     Complete  Active      9/2/2006
# 4        97393   46844453       Youth     Complete  Active      8/3/2004
# ..         ...        ...         ...          ...     ...           ...
# 310      97393   46858120       Youth     Complete  Active     3/29/2004
# 311      97393   48846586       Youth     Complete  Active     5/22/2003
# 312      97393   46863569       Youth     Complete  Active     9/27/2003
# 313      97393   46863548       Youth     Complete  Active     7/30/2003
# 314      97393   46865112       Youth     Complete  Active     2/22/2003
#
#                Housing Status          Street Address  Apt./Unit  \
# ...

# %%
# Columns and data types
students_df.dtypes
# Out:
# Agency ID                                       int64
# Person ID                                       int64
# Person Type                                    object
# Registration                                   object
# Status                                         object
# Date of Birth                                  object
# Housing Status                                 object
# Street Address                                 object
# Apt./Unit                                     float64
# City                                           object
# State                                          object
# Zip                                             int64
# Race/Ethnicity                                 object
# Specify Ethnicity                              object
# Home Language                                  object
# Specify Language                               object
# Gender                                         object
# ...

# %%
students_df.drop(columns=['Agency ID','Person Type','Registration','Specify Language','Street Address','State','Specify Ethnicity','SFUSD record? (y/n)', 'Status','Specify School Attending','Gender Identity Specify','Sexual Orientation/Sexual Identity Specify'])
# Out:
#      Person ID Date of Birth            Housing Status           City    Zip  \
# 0     46846158     9/14/2003  Permanent/Stable Housing  San Francisco  94112
# 1     46857740     4/15/2003  Permanent/Stable Housing  San Francisco  94115
# 2     47821880     6/27/2002  Permanent/Stable Housing  San Francisco  94102
# 3     46893469      9/2/2006  Permanent/Stable Housing  San Francisco  94129
# 4     46844453      8/3/2004  Permanent/Stable Housing  San Francisco  94118
# ..         ...           ...                       ...            ...    ...
# 310   46858120     3/29/2004  Permanent/Stable Housing  San Francisco  94109
# 311   48846586     5/22/2003  Permanent/Stable Housing  San Francisco  94132
# 312   46863569     9/27/2003  Permanent/Stable Housing  San Francisco  94134
# 313   46863548     7/30/2003  Permanent/Stable Housing  San Francisco  94134
# 314   46865112     2/22/2003  Permanent/Stable Housing  San Francisco  94110
#
# ...
