# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import numpy as np
import sklearn
import re
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from config_ea import db_password

# %%
# Upload file, convert to dataframe
students_df = pd.read_csv('../CSP_Data/student_demographic.csv')
students_df
# Out:
#      Agency ID  Person ID Person Type Registration  Status Date of Birth  \
# 0        97393   46846158       Youth     Complete  Active     9/14/2003
# 1        97393   46857740       Youth     Complete  Active     4/15/2003
# 2        97393   47821880       Youth     Complete  Active     6/27/2002
# 3        97393   46893469       Youth     Complete  Active      9/2/2006
# 4        97393   46844453       Youth     Complete  Active      8/3/2004
# ..         ...        ...         ...          ...     ...           ...
# 310      97393   46858120       Youth     Complete  Active     3/29/2004
# 311      97393   48846586       Youth     Complete  Active     5/22/2003
# 312      97393   46863569       Youth     Complete  Active     9/27/2003
# 313      97393   46863548       Youth     Complete  Active     7/30/2003
# 314      97393   46865112       Youth     Complete  Active     2/22/2003
#
#                Housing Status          Street Address  Apt./Unit  \
# 0    Permanent/Stable Housing           591 Flood Ave        NaN
# 1    Permanent/Stable Housing           1153 Scott St        NaN
# 2    Permanent/Stable Housing   145 Taylor St Apt 302        NaN
# 3    Permanent/Stable Housing  1532 Pershing Dr Apt D        NaN
# 4    Permanent/Stable Housing            144 10th Ave        NaN
# ..                        ...                     ...        ...
# 310  Permanent/Stable Housing      1410 Sacramento St        NaN
# 311  Permanent/Stable Housing         131 Victoria St        NaN
# 312  Permanent/Stable Housing          336 Wayland St        NaN
# 313  Permanent/Stable Housing      1340 Sunnydale Ave        NaN
# 314  Permanent/Stable Housing      44 Patton St Apt B        NaN
#
#               City  ... Sexual Orientation/Sexual Identity Specify  \
# 0    San Francisco  ...                                        NaN
# 1    San Francisco  ...                                        NaN
# 2    San Francisco  ...                                        NaN
# 3    San Francisco  ...                                        NaN
# 4    San Francisco  ...                                        NaN
# ..             ...  ...                                        ...
# 310  San Francisco  ...                                        NaN
# 311  San Francisco  ...                                        NaN
# 312  San Francisco  ...                                        NaN
# 313  San Francisco  ...                                        NaN
# 314  San Francisco  ...                                        NaN
#
#        Educational Attainment              School Attending  \
# 0    Currently attending K-12                    Mission HS
# 1    Currently attending K-12                    Mission HS
# 2    Currently attending K-12                    Mission HS
# 3    Currently attending K-12                     Marina MS
# 4    Currently attending K-12                New SFUSD, EPC
# ..                        ...                           ...
# 310  Currently attending K-12                     Lowell HS
# 311                       NaN                           NaN
# 312  Currently attending K-12  Burton (Phillip and Sala) HS
# 313  Currently attending K-12  Burton (Phillip and Sala) HS
# 314  Currently attending K-12         Leadership HS Charter
#
#     Specify School Attending SFUSD record? (y/n) School Entry Date  \
# 0                        NaN               SFUSD         8/20/2018
# 1                        NaN               SFUSD         8/20/2018
# 2                        NaN               SFUSD         1/17/2019
# 3                        NaN               SFUSD         8/20/2018
# 4                        NaN               SFUSD         8/20/2018
# ..                       ...                 ...               ...
# 310                      NaN               SFUSD         8/20/2018
# 311                      NaN               SFUSD               NaN
# 312                      NaN               SFUSD         8/20/2018
# 313                      NaN               SFUSD         8/20/2018
# 314                      NaN               SFUSD         8/20/2018
#
#     SFUSD Entry Date K-12 Grade Level (FY18-19)  K-12 Grade Level (FY19-20)  \
# 0          2/10/2011                         10                          11
# 1          8/25/2008                         10                          11
# 2          1/17/2019                          9                          10
# 3          7/21/2017                          6                           7
# 4          8/24/2009                          9                          10
# ..               ...                        ...                         ...
# 310        8/24/2009                          9                          10
# 311              NaN                        NaN                          11
# 312        8/25/2008                         10                          11
# 313        8/25/2008                         10                          11
# 314        8/25/2008                         10                          11
#
#     Agency Enrollment Date
# 0          5/14/2019 12:13
# 1          10/2/2018 13:09
# 2          2/11/2020 10:41
# 3         11/16/2018 13:41
# 4          2/19/2020 14:43
# ..                     ...
# 310         10/2/2018 9:27
# 311        2/14/2020 10:10
# 312        2/12/2020 10:15
# 313        2/12/2020 10:16
# 314       12/20/2019 10:29
#
# [315 rows x 32 columns]

# %%
# Columns and data types
students_df.dtypes
# Out:
# Agency ID                                       int64
# Person ID                                       int64
# Person Type                                    object
# Registration                                   object
# Status                                         object
# Date of Birth                                  object
# Housing Status                                 object
# Street Address                                 object
# Apt./Unit                                     float64
# City                                           object
# State                                          object
# Zip                                             int64
# Race/Ethnicity                                 object
# Specify Ethnicity                              object
# Home Language                                  object
# Specify Language                               object
# Gender                                         object
# Gay/Lesbian/Bisexual                           object
# Sex at Birth                                  float64
# Gender Identity                                object
# Gender Identity Specify                       float64
# Sexual Orientation/Sexual Identity            float64
# Sexual Orientation/Sexual Identity Specify    float64
# Educational Attainment                         object
# School Attending                               object
# Specify School Attending                      float64
# SFUSD record? (y/n)                            object
# School Entry Date                              object
# SFUSD Entry Date                               object
# K-12 Grade Level (FY18-19)                     object
# K-12 Grade Level (FY19-20)                      int64
# Agency Enrollment Date                         object
# dtype: object

# %%
# Check if gender and gender identity have the same information profile
students_df['Gender'].value_counts()
# Out:
# Male                   159
# Female                 141
# Declined/Not Stated     13
# Transgender              2
# Name: Gender, dtype: int64

# %%
students_df['Gender Identity'].value_counts()
# Out:
# Male                   159
# Female                 141
# Declined/Not Stated     13
# Transgender              2
# Name: Gender Identity, dtype: int64

# %%
# Drop Uneccesary columns in Student Demographics
students_df = students_df.drop(columns=['Agency ID','Person Type','Gender Identity','Home Language','Registration','Specify Language','Housing Status','Street Address','Apt./Unit','State','Specify Ethnicity','SFUSD record? (y/n)', 'Status','Specify School Attending','Gender Identity Specify','Sexual Orientation/Sexual Identity Specify', 'Sexual Orientation/Sexual Identity', 'Gay/Lesbian/Bisexual', 
                                        'SFUSD Entry Date','Educational Attainment','Sex at Birth'])

# %%
students_df.columns
# Out:
# Index(['Person ID', 'Date of Birth', 'City', 'Zip', 'Race/Ethnicity', 'Gender',
#        'School Attending', 'School Entry Date', 'K-12 Grade Level (FY18-19)',
#        'K-12 Grade Level (FY19-20)', 'Agency Enrollment Date'],
#       dtype='object')

# %%
# Change Zip to Home Zip Codes

students_df= students_df.rename(columns={'Person ID':'Participant_ID', 'Date of Birth':'Date_of_Birth', 'City':'City', 'Zip':'Home_Zip_Code',
       'Race/Ethnicity':'Race_Ethnicity','Gender':'Gender', 'School Attending':'School_Attending',
       'School Entry Date':'School_Entry_Date', 'SFUSD Entry Date':'SFUSD_Entry_Date', 'K-12 Grade Level (FY18-19)':'Grade_Level_FY18_19',
       'K-12 Grade Level (FY19-20)':'Grade_Level_FY19_20', 'Agency Enrollment Date': 'CSP_Enrollment_Date'})

# %%
#Check Different Races/Ethnicities
students_df['Race_Ethnicity'].unique()
# Out:
# array(['White', 'Middle Eastern - Arab',
#        'Hispanic/Latino - Central American', 'Declined to state',
#        'Hispanic/Latino - Mexican/Mexican American',
#        'Hispanic/Latino - Other (specify below)', 'African American',
#        'Multiracial/Multiethnic', 'Other Black (specify below)',
#        'Hispanic/Latino - South American', 'Asian - Chinese',
#        'Asian - Filipino', 'Pacific Islander - Hawaiian',
#        'Other (specify below)', 'Asian - Japanese',
#        'Pacific Islander - Samoan', 'Asian - Other (specify below)',
#        'Asian - Khmer/Cambodian', 'Asian - Vietnamese'], dtype=object)

# %%
#Check the DataTypes
students_df.dtypes
# Out:
# Participant_ID          int64
# Date_of_Birth          object
# City                   object
# Home_Zip_Code           int64
# Race_Ethnicity         object
# Gender                 object
# School_Attending       object
# School_Entry_Date      object
# Grade_Level_FY18_19    object
# Grade_Level_FY19_20     int64
# CSP_Enrollment_Date    object
# dtype: object

# %%
# Fill Null values
students_df['School_Attending'].fillna('Unspecified', inplace=True)

# %%
#see if there are any null values
students_df.columns[students_df.isna().any()].value_counts()
# Out:
# Grade_Level_FY18_19    1
# School_Entry_Date      1
# dtype: int64

# %%
#Find the null values
#FOUND in row 311
students_df.isnull()
# Out:
#      Participant_ID  Date_of_Birth   City  Home_Zip_Code  Race_Ethnicity  \
# 0             False          False  False          False           False
# 1             False          False  False          False           False
# 2             False          False  False          False           False
# 3             False          False  False          False           False
# 4             False          False  False          False           False
# ..              ...            ...    ...            ...             ...
# 310           False          False  False          False           False
# 311           False          False  False          False           False
# 312           False          False  False          False           False
# 313           False          False  False          False           False
# 314           False          False  False          False           False
#
#      Gender  School_Attending  School_Entry_Date  Grade_Level_FY18_19  \
# 0     False             False              False                False
# 1     False             False              False                False
# 2     False             False              False                False
# 3     False             False              False                False
# 4     False             False              False                False
# ..      ...               ...                ...                  ...
# 310   False             False              False                False
# 311   False             False               True                 True
# 312   False             False              False                False
# 313   False             False              False                False
# 314   False             False              False                False
#
#      Grade_Level_FY19_20  CSP_Enrollment_Date
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                False
# 4                  False                False
# ..                   ...                  ...
# 310                False                False
# 311                False                False
# 312                False                False
# 313                False                False
# 314                False                False
#
# [315 rows x 11 columns]

# %%
#Drop the row with the null values 
students_df.dropna(how='any', inplace=True)

# %%
students_df['Grade_Level_FY18_19'].value_counts()
# Out:
# 10    110
# 9      85
# 8      26
# 6      26
# 5      22
# 7       9
# 4       7
# 11      7
# 3       6
# 2       6
# K       1
# Name: Grade_Level_FY18_19, dtype: int64

# %%
dirty_row = students_df.loc[students_df["Grade_Level_FY18_19"] == "K"]
dirty_row
# Out:
#      Participant_ID Date_of_Birth           City  Home_Zip_Code  \
# 158        47411223     2/13/2013  San Francisco          94103
#
#               Race_Ethnicity  Gender        School_Attending  \
# 158  Multiracial/Multiethnic  Female  Cobb (Dr William L) ES
#
#     School_Entry_Date Grade_Level_FY18_19  Grade_Level_FY19_20  \
# 158         8/30/2018                   K                    1
#
#     CSP_Enrollment_Date
# 158      8/6/2019 16:00

# %%
# Leave out row with value "K" for kindergarden
students_df = students_df[students_df["Grade_Level_FY18_19"] != "K"]

# %%
# Convert Date of Birth and agency enrollment date to Datetime
students_df['Date_of_Birth'] = pd.to_datetime(students_df['Date_of_Birth'])
students_df['School_Entry_Date'] = pd.to_datetime(students_df['School_Entry_Date'])
#also need School Entry Date or Drop column 
students_df['CSP_Enrollment_Date'] = pd.to_datetime(students_df['CSP_Enrollment_Date'], errors='coerce').dt.floor('d')

# %%
students_df['Grade_Level_FY18_19'] = students_df['Grade_Level_FY18_19'].astype(str).astype(int)

# %%
students_df.dtypes
# Out:
# Participant_ID                  int64
# Date_of_Birth          datetime64[ns]
# City                           object
# Home_Zip_Code                   int64
# Race_Ethnicity                 object
# Gender                         object
# School_Attending               object
# School_Entry_Date      datetime64[ns]
# Grade_Level_FY18_19             int32
# Grade_Level_FY19_20             int64
# CSP_Enrollment_Date    datetime64[ns]
# dtype: object

# %%
students_df["Race_Ethnicity"].value_counts()
# Out:
# Hispanic/Latinx                            98
# African American                           45
# Declined to state                          44
# White                                      41
# Asian - Chinese                            25
# Hispanic/Latino - Other (specify below)    18
# Multiracial/Multiethnic                    11
# Middle Eastern - Arab                       5
# Other (specify below)                       5
# Asian - Filipino                            4
# Asian - Other (specify below)               2
# Asian - Japanese                            1
# Asian - Khmer/Cambodian                     1
# Pacific Islander - Hawaiian                 1
# Other Black (specify below)                 1
# Pacific Islander - Samoan                   1
# Asian - Vietnamese                          1
# Name: Race_Ethnicity, dtype: int64

# %%
# USE LOC and REGULAR EXPRESSION INSTEAD - To fix the issue with the Hispanic/Latino-Other 
#Combine Hispanic/Latino all to one category
# Add the Race/Ethnicity to a list that you wish to change.
race_ethnicity_to_change = ["Hispanic/Latino - Central American", "Hispanic/Latino - Mexican/Mexican American","Hispanic/Latino - Other (specify below)","Hispanic/Latino - South American",]

# Iterate through the words in the "race/ethincity to change" list and replace them with an Hispanic/Latino for bucketing purposes.
for word in race_ethnicity_to_change:
    students_df["Race_Ethnicity"] = students_df["Race_Ethnicity"].str.replace(word,"Hispanic/Latinx")

# %%
students_df["Race_Ethnicity"].value_counts()
# Out:
# Hispanic/Latinx                            98
# African American                           45
# Declined to state                          44
# White                                      41
# Asian - Chinese                            25
# Hispanic/Latino - Other (specify below)    18
# Multiracial/Multiethnic                    11
# Middle Eastern - Arab                       5
# Other (specify below)                       5
# Asian - Filipino                            4
# Asian - Other (specify below)               2
# Asian - Japanese                            1
# Asian - Khmer/Cambodian                     1
# Pacific Islander - Hawaiian                 1
# Other Black (specify below)                 1
# Pacific Islander - Samoan                   1
# Asian - Vietnamese                          1
# Name: Race_Ethnicity, dtype: int64

# %%
#Create and Asian/Pacific Islander Bucket under Race/Ethnicity
#create a list for Asian/Pacific Islander
asian_pi = ["Asian - Chinese","Asian - Filipino", "Asian - Other (specify below) ", "Asian - Vietnamese", "Asian - Khmer/Cambodian", 
            "Asian - Japanese", "Pacific Islander - Samoan", "Pacific Islander - Hawaiian"]
# Iterate through the words in the "race/ethincity to change" list and replace them with an Hispanic/Latino for bucketing purposes.
for word in asian_pi:
    students_df["Race_Ethnicity"] = students_df["Race_Ethnicity"].str.replace(word,"Asian/Pacific Islander")

# %%
# Group remaining groups into larger categories
students_df['Race_Ethnicity'] = students_df['Race_Ethnicity'].replace({
    'Asian - Other (specify below)':'Asian/Pacific Islander',
    'Hispanic/Latino':'Hispanic/Latinx',
    'Other Black (specify below)':'African American/Other Black',
    'African American':'African American/Other Black',
    'Other (specify below)':'Declined to state/Other',
    'Declined to state':'Declined to state/Other',
    'Middle Eastern - Arab':'Middle Eastern/Arab',
    'Hispanic/Latino - Other (specify below)': 'Hispanic/Latinx',
    'White':'Caucasian/ White'
   })
students_df['Race_Ethnicity'].value_counts()
# Out:
# Hispanic/Latinx                 116
# Declined to state/Other          49
# African American/Other Black     46
# Caucasian/ White                 41
# Asian/Pacific Islander           36
# Multiracial/Multiethnic          11
# Middle Eastern/Arab               5
# Name: Race_Ethnicity, dtype: int64

# %%
#Check Different Schools
students_df['School_Attending'].value_counts()
# Out:
# Mission HS                             129
# Aptos MS                                30
# Lowell HS                               19
# Leadership HS Charter                   15
# New SFUSD, EPC                           6
# Lincoln (Abraham) HS                     6
# Lilienthal (Claire) K-8                  5
# Wells (Ida B) HS                         5
# Balboa HS                                5
# Glen Park ES                             4
# Lick (James) MS                          4
# Everett MS                               4
# Rooftop K-8                              4
# Hoover (Herbert) MS                      4
# Independence HS                          3
# Hillcrest ES                             3
# Burton (Phillip and Sala) HS             3
# Lakeshore ES                             3
# Galileo HS                               3
# Asawa (Ruth) SOTA HS                     3
# Carver (Dr George W) ES                  2
# Carmichael (Bessie) K-8                  2
# Milk (Harvey) Civil Right ES             2
# Parks (Rosa) ES                          2
# KIPP Bayview Academy MS Charter          2
# Marina MS                                2
# Clarendon ES                             2
# Denman (James) MS                        2
# Roosevelt MS                             2
# Creative Arts K-8 Charter                2
# Taylor (Edward R) ES                     2
# Giannini (A.P.) MS                       2
# KIPP SF College Preparatory Charter      1
# King (Thomas Starr) ES                   1
# Brown Jr. (Willie) MS                    1
# Presidio MS                              1
# Marshall (Thurgood) HS                   1
# Special Education Private/Parochial      1
# Ortega (Jose) ES                         1
# Stevenson (Robert Louis) ES              1
# The Academy - SF @ McAteer HS            1
# Chin (John Yehall) ES                    1
# Yu (Alice Fong) K-8                      1
# SF International HS                      1
# Serra (Junipero) ES                      1
# Washington (George) HS                   1
# McKinley ES                              1
# Sheridan ES                              1
# Wallenberg (Raoul) HS                    1
# Buena Vista Horace Mann K-8              1
# Peabody (George) ES                      1
# King Jr (Dr Martin L) MS                 1
# Cobb (Dr William L) ES                   1
# El Dorado ES                             1
# Name: School_Attending, dtype: int64

# %%
# Removing comma from a school
students_df['School_Attending'] = students_df['School_Attending'].replace({
    'New SFUSD, EPC':'New SFUSD - EPC'
   })
students_df['School_Attending'].value_counts()
# Out:
# Mission HS                             129
# Aptos MS                                30
# Lowell HS                               19
# Leadership HS Charter                   15
# Lincoln (Abraham) HS                     6
# New SFUSD - EPC                          6
# Lilienthal (Claire) K-8                  5
# Wells (Ida B) HS                         5
# Balboa HS                                5
# Glen Park ES                             4
# Lick (James) MS                          4
# Rooftop K-8                              4
# Everett MS                               4
# Hoover (Herbert) MS                      4
# Independence HS                          3
# Hillcrest ES                             3
# Burton (Phillip and Sala) HS             3
# Lakeshore ES                             3
# Galileo HS                               3
# Asawa (Ruth) SOTA HS                     3
# Carver (Dr George W) ES                  2
# Carmichael (Bessie) K-8                  2
# Milk (Harvey) Civil Right ES             2
# Parks (Rosa) ES                          2
# KIPP Bayview Academy MS Charter          2
# Marina MS                                2
# Clarendon ES                             2
# Denman (James) MS                        2
# Roosevelt MS                             2
# Taylor (Edward R) ES                     2
# Giannini (A.P.) MS                       2
# Creative Arts K-8 Charter                2
# Yu (Alice Fong) K-8                      1
# King (Thomas Starr) ES                   1
# Brown Jr. (Willie) MS                    1
# Presidio MS                              1
# Marshall (Thurgood) HS                   1
# Special Education Private/Parochial      1
# Ortega (Jose) ES                         1
# Stevenson (Robert Louis) ES              1
# The Academy - SF @ McAteer HS            1
# KIPP SF College Preparatory Charter      1
# Chin (John Yehall) ES                    1
# SF International HS                      1
# Serra (Junipero) ES                      1
# Washington (George) HS                   1
# McKinley ES                              1
# Sheridan ES                              1
# Wallenberg (Raoul) HS                    1
# Buena Vista Horace Mann K-8              1
# Peabody (George) ES                      1
# King Jr (Dr Martin L) MS                 1
# Cobb (Dr William L) ES                   1
# El Dorado ES                             1
# Name: School_Attending, dtype: int64

# %%
# Group One count schools    
students_df['School_Attending'] = students_df['School_Attending'].replace({
    'Ortega (Jose) ES':'Other', 'Wallenberg (Raoul) HS':'Other','Brown Jr. (Willie) MS':'Other',
    'KIPP SF College Preparatory Charter':'Other','Buena Vista Horace Mann K-8':'Other',
    'King Jr (Dr Martin L) MS':'Other','Yu (Alice Fong) K-8':'Other','Peabody (George) ES':'Other',
    'SF International HS':'Other','Washington (George) HS':'Other',
    'Presidio MS':'Other','Marshall (Thurgood) HS':'Other','Special Education Private/Parochial':'Other',
    'The Academy - SF @ McAteer HS':'Other',
        'King (Thomas Starr) ES':'Other','Sheridan ES':'Other','Stevenson (Robert Louis) ES':'Other',
        'Sheridan ES':'Other','Stevenson (Robert Louis) ES':'Other','McKinley ES':'Other','Chin (John Yehall) ES':'Other',
                     'Serra (Junipero) ES':'Other','El Dorado ES':'Other','Cobb (Dr William L) ES':'Other'
   })
students_df['School_Attending'].value_counts()
# Out:
# Mission HS                         129
# Aptos MS                            30
# Other                               22
# Lowell HS                           19
# Leadership HS Charter               15
# Lincoln (Abraham) HS                 6
# New SFUSD - EPC                      6
# Wells (Ida B) HS                     5
# Lilienthal (Claire) K-8              5
# Balboa HS                            5
# Rooftop K-8                          4
# Everett MS                           4
# Hoover (Herbert) MS                  4
# Glen Park ES                         4
# Lick (James) MS                      4
# Lakeshore ES                         3
# Hillcrest ES                         3
# Asawa (Ruth) SOTA HS                 3
# Burton (Phillip and Sala) HS         3
# Galileo HS                           3
# Independence HS                      3
# Parks (Rosa) ES                      2
# Marina MS                            2
# Carver (Dr George W) ES              2
# Taylor (Edward R) ES                 2
# Creative Arts K-8 Charter            2
# Milk (Harvey) Civil Right ES         2
# Denman (James) MS                    2
# Roosevelt MS                         2
# Carmichael (Bessie) K-8              2
# KIPP Bayview Academy MS Charter      2
# Clarendon ES                         2
# Giannini (A.P.) MS                   2
# Name: School_Attending, dtype: int64

# %%
students_df["School_Attending"].value_counts()
# Out:
# Mission HS                         129
# Aptos MS                            30
# Other                               22
# Lowell HS                           19
# Leadership HS Charter               15
# Lincoln (Abraham) HS                 6
# New SFUSD - EPC                      6
# Wells (Ida B) HS                     5
# Lilienthal (Claire) K-8              5
# Balboa HS                            5
# Rooftop K-8                          4
# Everett MS                           4
# Hoover (Herbert) MS                  4
# Glen Park ES                         4
# Lick (James) MS                      4
# Lakeshore ES                         3
# Hillcrest ES                         3
# Asawa (Ruth) SOTA HS                 3
# Burton (Phillip and Sala) HS         3
# Galileo HS                           3
# Independence HS                      3
# Parks (Rosa) ES                      2
# Marina MS                            2
# Carver (Dr George W) ES              2
# Taylor (Edward R) ES                 2
# Creative Arts K-8 Charter            2
# Milk (Harvey) Civil Right ES         2
# Denman (James) MS                    2
# Roosevelt MS                         2
# Carmichael (Bessie) K-8              2
# KIPP Bayview Academy MS Charter      2
# Clarendon ES                         2
# Giannini (A.P.) MS                   2
# Name: School_Attending, dtype: int64

# %%
#See how many different cities are counted
students_df["City"].unique()
# Out:
# array(['San Francisco', 'SAN FRANCISCO', 'Daly City', 'Richmond'],
#       dtype=object)

# %%
#See City Breakdown
students_df["City"].value_counts()
# Out:
# San Francisco    291
# SAN FRANCISCO      5
# Daly City          4
# Richmond           4
# Name: City, dtype: int64

# %%
# Make a function to replace SAN FRANCISO with San Francisco 
bad_text= ["SAN FRANCISCO"]

for word in bad_text:
    students_df["City"] = students_df["City"].str.replace(word, "San Francisco")

# %%
#Check if it worked
students_df["City"].value_counts()
# Out:
# San Francisco    296
# Daly City          4
# Richmond           4
# Name: City, dtype: int64

# %%
#See Zip Code Distribution
students_df["Home_Zip_Code"].value_counts()
# Out:
# 94110    53
# 94124    46
# 94112    43
# 94134    32
# 94132    18
# 94103    14
# 94114    11
# 94122    10
# 94115     9
# 94131     9
# 94102     9
# 94118     8
# 94116     7
# 94109     6
# 94121     6
# 94107     5
# 94127     4
# 94015     2
# 94014     2
# 94804     2
# 94117     2
# 94129     2
# 94130     1
# 94806     1
# 94805     1
# 94158     1
# Name: Home_Zip_Code, dtype: int64

# %%
# Find the Age students enroll in CSP
students_df['CSP_Approx_Enrollment_Age'] = (students_df['CSP_Enrollment_Date'] - students_df['Date_of_Birth']).dt.days
students_df
# Out:
#      Participant_ID Date_of_Birth           City  Home_Zip_Code  \
# 0          46846158    2003-09-14  San Francisco          94112
# 1          46857740    2003-04-15  San Francisco          94115
# 2          47821880    2002-06-27  San Francisco          94102
# 3          46893469    2006-09-02  San Francisco          94129
# 4          46844453    2004-08-03  San Francisco          94118
# ..              ...           ...            ...            ...
# 309        46896750    2004-04-10  San Francisco          94122
# 310        46858120    2004-03-29  San Francisco          94109
# 312        46863569    2003-09-27  San Francisco          94134
# 313        46863548    2003-07-30  San Francisco          94134
# 314        46865112    2003-02-22  San Francisco          94110
#
#               Race_Ethnicity  Gender              School_Attending  \
# 0           Caucasian/ White    Male                    Mission HS
# 1        Middle Eastern/Arab    Male                    Mission HS
# 2            Hispanic/Latinx  Female                    Mission HS
# 3    Declined to state/Other  Female                     Marina MS
# 4    Declined to state/Other    Male               New SFUSD - EPC
# ..                       ...     ...                           ...
# 309  Declined to state/Other  Female                     Lowell HS
# 310  Declined to state/Other  Female                     Lowell HS
# 312   Asian/Pacific Islander    Male  Burton (Phillip and Sala) HS
# 313  Declined to state/Other  Female  Burton (Phillip and Sala) HS
# 314          Hispanic/Latinx  Female         Leadership HS Charter
#
#     School_Entry_Date  Grade_Level_FY18_19  Grade_Level_FY19_20  \
# 0          2018-08-20                   10                   11
# 1          2018-08-20                   10                   11
# 2          2019-01-17                    9                   10
# 3          2018-08-20                    6                    7
# 4          2018-08-20                    9                   10
# ..                ...                  ...                  ...
# 309        2018-08-20                    9                   10
# 310        2018-08-20                    9                   10
# 312        2018-08-20                   10                   11
# 313        2018-08-20                   10                   11
# 314        2018-08-20                   10                   11
#
#     CSP_Enrollment_Date  CSP_Approx_Enrollment_Age
# 0            2019-05-14                       5721
# 1            2018-10-02                       5649
# 2            2020-02-11                       6438
# 3            2018-11-16                       4458
# 4            2020-02-19                       5678
# ..                  ...                        ...
# 309          2018-10-02                       5288
# 310          2018-10-02                       5300
# 312          2020-02-12                       5982
# 313          2020-02-12                       6041
# 314          2019-12-20                       6145
#
# [304 rows x 12 columns]

# %%
# Convert days to approximate years in CSP Enrollment Age
# Years needs to be approximate because of the existence of leap years 
students_df["CSP_Approx_Enrollment_Age"] = (students_df["CSP_Approx_Enrollment_Age"]/365).round(1)
students_df
# Out:
#      Participant_ID Date_of_Birth           City  Home_Zip_Code  \
# 0          46846158    2003-09-14  San Francisco          94112
# 1          46857740    2003-04-15  San Francisco          94115
# 2          47821880    2002-06-27  San Francisco          94102
# 3          46893469    2006-09-02  San Francisco          94129
# 4          46844453    2004-08-03  San Francisco          94118
# ..              ...           ...            ...            ...
# 309        46896750    2004-04-10  San Francisco          94122
# 310        46858120    2004-03-29  San Francisco          94109
# 312        46863569    2003-09-27  San Francisco          94134
# 313        46863548    2003-07-30  San Francisco          94134
# 314        46865112    2003-02-22  San Francisco          94110
#
#               Race_Ethnicity  Gender              School_Attending  \
# 0           Caucasian/ White    Male                    Mission HS
# 1        Middle Eastern/Arab    Male                    Mission HS
# 2            Hispanic/Latinx  Female                    Mission HS
# 3    Declined to state/Other  Female                     Marina MS
# 4    Declined to state/Other    Male               New SFUSD - EPC
# ..                       ...     ...                           ...
# 309  Declined to state/Other  Female                     Lowell HS
# 310  Declined to state/Other  Female                     Lowell HS
# 312   Asian/Pacific Islander    Male  Burton (Phillip and Sala) HS
# 313  Declined to state/Other  Female  Burton (Phillip and Sala) HS
# 314          Hispanic/Latinx  Female         Leadership HS Charter
#
#     School_Entry_Date  Grade_Level_FY18_19  Grade_Level_FY19_20  \
# 0          2018-08-20                   10                   11
# 1          2018-08-20                   10                   11
# 2          2019-01-17                    9                   10
# 3          2018-08-20                    6                    7
# 4          2018-08-20                    9                   10
# ..                ...                  ...                  ...
# 309        2018-08-20                    9                   10
# 310        2018-08-20                    9                   10
# 312        2018-08-20                   10                   11
# 313        2018-08-20                   10                   11
# 314        2018-08-20                   10                   11
#
#     CSP_Enrollment_Date  CSP_Approx_Enrollment_Age
# 0            2019-05-14                       15.7
# 1            2018-10-02                       15.5
# 2            2020-02-11                       17.6
# 3            2018-11-16                       12.2
# 4            2020-02-19                       15.6
# ..                  ...                        ...
# 309          2018-10-02                       14.5
# 310          2018-10-02                       14.5
# 312          2020-02-12                       16.4
# 313          2020-02-12                       16.6
# 314          2019-12-20                       16.8
#
# [304 rows x 12 columns]

# %%
y_axis = students_df['CSP_Approx_Enrollment_Age']
x_axis = students_df['CSP_Enrollment_Date']
plt.scatter(x_axis,y_axis)

# %%
students_df.dtypes
# Out:
# Participant_ID                        int64
# Date_of_Birth                datetime64[ns]
# City                                 object
# Home_Zip_Code                         int64
# Race_Ethnicity                       object
# Gender                               object
# School_Attending                     object
# School_Entry_Date            datetime64[ns]
# Grade_Level_FY18_19                   int32
# Grade_Level_FY19_20                   int64
# CSP_Enrollment_Date          datetime64[ns]
# CSP_Approx_Enrollment_Age           float64
# dtype: object

# %%
len(students_df)
# Out:
# 304

# %% [markdown]
# # Connect the cleaned DF to PGAdmin

# %%
from sqlalchemy.types import Integer, Text, String, DateTime

# %%
#Load Data 
db_string = f"postgres://postgres:{db_password}@127.0.0.1:62660/City_Surf"
engine = create_engine(db_string)
students_df.to_sql(name='Student_Demo', con=engine, if_exists = 'replace')

# %% [markdown]
# # Export Clean Student Data for use in Tableau

# %%
students_df.to_csv(r'../CSP_Data/student_demo_cleaned.csv',index=False)

# %%
students_df['Race_Ethnicity'].value_counts()
